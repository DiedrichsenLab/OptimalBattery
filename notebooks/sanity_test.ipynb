# %%
import numpy as np

# %%
A = np.random.normal(0,1,(3,10))
A[2,:]=0
A = A - A.mean(axis=0)
np.linalg.eig(A@A.T)
# Out:
# EigResult(eigenvalues=array([1.77635684e-15, 7.12935013e+00, 1.12125537e+01]), eigenvectors=array([[-0.57735027, -0.81576733, -0.03450126],
#        [-0.57735027,  0.43776263, -0.6892246 ],
#        [-0.57735027,  0.37800469,  0.72372586]]))
