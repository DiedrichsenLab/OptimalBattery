# %%
from OptimalBattery import simulate as sim
import numpy as np
import matplotlib.pyplot as plt
import HierarchBayesParcel.evaluation as ev
import torch as pt
import OptimalBattery.util as ut
from numpy.linalg import eigh
from scipy.stats import pearsonr
from Functional_Fusion.dataset import DataSetMDTB
import PcmPy as pcm
import seaborn as sns
import os
import pandas as pd
import pickle
from PcmPy.sim import make_signal
from OptimalBattery.plot import plot_correlations
from sklearn.cluster import MiniBatchKMeans
from sklearn.manifold import spectral_embedding

# %% [markdown]
# # generate true Us

# %%
n_subs = 24
n_parcel = 4
n_voxels  = 100
n_tasks = 29
offsets = [1e-12,1e-10,1e-8,1e-6,1e-4,1e-2,1,1e2,1e4,1e6,1e8,1e10,1e12]

# %%
U_true = sim.generate_Us(s= n_subs, k = n_parcel, p = n_voxels, type= 'hard')
plt.imshow(U_true[2])

# %% [markdown]
# # Generate test data (random Vs)

# %%
def evaluate_combinations(D, VLib, ytest, vtest):
    # Create a new column with combinations as tuples to make them hashable
    D['combination_tuple'] = D['combination'].apply(lambda x: tuple(x))
    
    # Get unique combinations
    unique_combinations = D['combination_tuple'].unique()
    
    # Initialize a dictionary to store cos_HBP for each unique combination
    mse_ols_dict = {}
    cos_ols_dict = {}

    ytest = pt.tensor(ytest,dtype=pt.float32)
    vtest = pt.tensor(vtest,dtype=pt.float32)
    
    # Loop over each unique combination
    for i, comb_tuple in enumerate(unique_combinations):
        if i % 100 == 0:
            print(f"Processing combination: {i}")
        
        # Get the task subset indices and corresponding data
        task_subset_indices = list(comb_tuple)
        V_subset = VLib[task_subset_indices, :]
        V_subset = V_subset - np.mean(V_subset, axis=0)
        V_subset = V_subset / np.sqrt(np.sum(V_subset**2, axis=0))
        rank_V_subset = np.linalg.matrix_rank(V_subset)
        if rank_V_subset < V_subset.shape[1]:
            continue  # Skip this combination if the rank condition is not met

        y_subset = V_subset @ U_true
        y_subset = y_subset + np.random.normal(0, 1, y_subset.shape)

        U_hat_ols = sim.estimate_Us_ols(y_subset, V_subset)
        mse_ols = sim.U_MSE(U_true, U_hat_ols)
        
        U_hat_ols = pt.tensor(U_hat_ols,dtype=pt.float32)
        cos_ols = ev.coserr(ytest,vtest,U_hat_ols).mean().cpu().numpy()
        cos_ols = cos_ols.item()
        
        # Store the result in the dictionary
        mse_ols_dict[comb_tuple] = mse_ols
        cos_ols_dict[comb_tuple] = cos_ols
    
    # Map the computed cos_HBP values back to the DataFrame
    D['mse_ols'] = D['combination_tuple'].map(mse_ols_dict)
    D['cos_ols'] = D['combination_tuple'].map(cos_ols_dict)
    
    return D

# %% [markdown]
# # Random V Library

# %%
VL_rand = Vs = np.random.normal(0, 1, (n_tasks, n_parcel))
VL_rand = VL_rand - np.mean(VL_rand, axis=0)
VL_rand = VL_rand / np.sqrt(np.sum(VL_rand**2, axis=0))
GL_rand = VL_rand @ VL_rand.T


V_test = VL_rand
y_test = V_test @ U_true
y_test = y_test + np.random.normal(0, 1, y_test.shape)

fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].imshow(VL_rand)
ax[0].set_title('VL_rand')

ax[1].imshow(GL_rand)
ax[1].set_title('GL_rand')

plt.show()

# %%
D_rand = ut.build_combinations(GL_rand, strategy='random',offs = offsets,n_iter=40000,n_tasks=8,seed=300)
D_rand = evaluate_combinations(D_rand, VL_rand, y_test, V_test)
# Out:
# building0
# building10000
# building20000
# building30000
# Processing combination: 0
# Processing combination: 100
# Processing combination: 200
# Processing combination: 300
# Processing combination: 400
# Processing combination: 500
# Processing combination: 600
# Processing combination: 700
# Processing combination: 800
# Processing combination: 900
# Processing combination: 1000
# Processing combination: 1100
# Processing combination: 1200
# Processing combination: 1300
# Processing combination: 1400
# Processing combination: 1500
# Processing combination: 1600
# Processing combination: 1700
# Processing combination: 1800
# Processing combination: 1900
# Processing combination: 2000
# Processing combination: 2100
# Processing combination: 2200
# Processing combination: 2300
# Processing combination: 2400
# Processing combination: 2500
# Processing combination: 2600
# Processing combination: 2700
# Processing combination: 2800
# Processing combination: 2900
# Processing combination: 3000
# Processing combination: 3100
# Processing combination: 3200
# Processing combination: 3300
# Processing combination: 3400
# Processing combination: 3500
# Processing combination: 3600
# Processing combination: 3700
# Processing combination: 3800
# Processing combination: 3900
# Processing combination: 4000
# Processing combination: 4100
# Processing combination: 4200
# Processing combination: 4300
# Processing combination: 4400
# Processing combination: 4500
# Processing combination: 4600
# Processing combination: 4700
# Processing combination: 4800
# Processing combination: 4900
# Processing combination: 5000
# Processing combination: 5100
# Processing combination: 5200
# Processing combination: 5300
# Processing combination: 5400
# Processing combination: 5500
# Processing combination: 5600
# Processing combination: 5700
# Processing combination: 5800
# Processing combination: 5900
# Processing combination: 6000
# Processing combination: 6100
# Processing combination: 6200
# Processing combination: 6300
# Processing combination: 6400
# Processing combination: 6500
# Processing combination: 6600
# Processing combination: 6700
# Processing combination: 6800
# Processing combination: 6900
# Processing combination: 7000
# Processing combination: 7100
# Processing combination: 7200
# Processing combination: 7300
# Processing combination: 7400
# Processing combination: 7500
# Processing combination: 7600
# Processing combination: 7700
# Processing combination: 7800
# Processing combination: 7900
# Processing combination: 8000
# Processing combination: 8100
# Processing combination: 8200
# Processing combination: 8300
# Processing combination: 8400
# Processing combination: 8500
# Processing combination: 8600
# Processing combination: 8700
# Processing combination: 8800
# Processing combination: 8900
# Processing combination: 9000
# Processing combination: 9100
# Processing combination: 9200
# Processing combination: 9300
# Processing combination: 9400
# Processing combination: 9500
# Processing combination: 9600
# Processing combination: 9700
# Processing combination: 9800
# Processing combination: 9900
# Processing combination: 10000
# Processing combination: 10100
# Processing combination: 10200
# Processing combination: 10300
# Processing combination: 10400
# Processing combination: 10500
# Processing combination: 10600
# Processing combination: 10700
# Processing combination: 10800
# Processing combination: 10900
# Processing combination: 11000
# Processing combination: 11100
# Processing combination: 11200
# Processing combination: 11300
# Processing combination: 11400
# Processing combination: 11500
# Processing combination: 11600
# Processing combination: 11700
# Processing combination: 11800
# Processing combination: 11900
# Processing combination: 12000
# Processing combination: 12100
# Processing combination: 12200
# Processing combination: 12300
# Processing combination: 12400
# Processing combination: 12500
# Processing combination: 12600
# Processing combination: 12700
# Processing combination: 12800
# Processing combination: 12900
# Processing combination: 13000
# Processing combination: 13100
# Processing combination: 13200
# Processing combination: 13300
# Processing combination: 13400
# Processing combination: 13500
# Processing combination: 13600
# Processing combination: 13700
# Processing combination: 13800
# Processing combination: 13900
# Processing combination: 14000
# Processing combination: 14100
# Processing combination: 14200
# Processing combination: 14300
# Processing combination: 14400
# Processing combination: 14500
# Processing combination: 14600
# Processing combination: 14700
# Processing combination: 14800
# Processing combination: 14900
# Processing combination: 15000
# Processing combination: 15100
# Processing combination: 15200
# Processing combination: 15300
# Processing combination: 15400
# Processing combination: 15500
# Processing combination: 15600
# Processing combination: 15700
# Processing combination: 15800
# Processing combination: 15900
# Processing combination: 16000
# Processing combination: 16100
# Processing combination: 16200
# Processing combination: 16300
# Processing combination: 16400
# Processing combination: 16500
# Processing combination: 16600
# Processing combination: 16700
# Processing combination: 16800
# Processing combination: 16900
# Processing combination: 17000
# Processing combination: 17100
# Processing combination: 17200
# Processing combination: 17300
# Processing combination: 17400
# Processing combination: 17500
# Processing combination: 17600
# Processing combination: 17700
# Processing combination: 17800
# Processing combination: 17900
# Processing combination: 18000
# Processing combination: 18100
# Processing combination: 18200
# Processing combination: 18300
# Processing combination: 18400
# Processing combination: 18500
# Processing combination: 18600
# Processing combination: 18700
# Processing combination: 18800
# Processing combination: 18900
# Processing combination: 19000
# Processing combination: 19100
# Processing combination: 19200
# Processing combination: 19300
# Processing combination: 19400
# Processing combination: 19500
# Processing combination: 19600
# Processing combination: 19700
# Processing combination: 19800
# Processing combination: 19900
# Processing combination: 20000
# Processing combination: 20100
# Processing combination: 20200
# Processing combination: 20300
# Processing combination: 20400
# Processing combination: 20500
# Processing combination: 20600
# Processing combination: 20700
# Processing combination: 20800
# Processing combination: 20900
# Processing combination: 21000
# Processing combination: 21100
# Processing combination: 21200
# Processing combination: 21300
# Processing combination: 21400
# Processing combination: 21500
# Processing combination: 21600
# Processing combination: 21700
# Processing combination: 21800
# Processing combination: 21900
# Processing combination: 22000
# Processing combination: 22100
# Processing combination: 22200
# Processing combination: 22300
# Processing combination: 22400
# Processing combination: 22500
# Processing combination: 22600
# Processing combination: 22700
# Processing combination: 22800
# Processing combination: 22900
# Processing combination: 23000
# Processing combination: 23100
# Processing combination: 23200
# Processing combination: 23300
# Processing combination: 23400
# Processing combination: 23500
# Processing combination: 23600
# Processing combination: 23700
# Processing combination: 23800
# Processing combination: 23900
# Processing combination: 24000
# Processing combination: 24100
# Processing combination: 24200
# Processing combination: 24300
# Processing combination: 24400
# Processing combination: 24500
# Processing combination: 24600
# Processing combination: 24700
# Processing combination: 24800
# Processing combination: 24900
# Processing combination: 25000
# Processing combination: 25100
# Processing combination: 25200
# Processing combination: 25300
# Processing combination: 25400
# Processing combination: 25500
# Processing combination: 25600
# Processing combination: 25700
# Processing combination: 25800
# Processing combination: 25900
# Processing combination: 26000
# Processing combination: 26100
# Processing combination: 26200
# Processing combination: 26300
# Processing combination: 26400
# Processing combination: 26500
# Processing combination: 26600
# Processing combination: 26700
# Processing combination: 26800
# Processing combination: 26900
# Processing combination: 27000
# Processing combination: 27100
# Processing combination: 27200
# Processing combination: 27300
# Processing combination: 27400
# Processing combination: 27500
# Processing combination: 27600
# Processing combination: 27700
# Processing combination: 27800
# Processing combination: 27900
# Processing combination: 28000
# Processing combination: 28100
# Processing combination: 28200
# Processing combination: 28300
# Processing combination: 28400
# Processing combination: 28500
# Processing combination: 28600
# Processing combination: 28700
# Processing combination: 28800
# Processing combination: 28900
# Processing combination: 29000
# Processing combination: 29100
# Processing combination: 29200
# Processing combination: 29300
# Processing combination: 29400
# Processing combination: 29500
# Processing combination: 29600
# Processing combination: 29700
# Processing combination: 29800
# Processing combination: 29900
# Processing combination: 30000
# Processing combination: 30100
# Processing combination: 30200
# Processing combination: 30300
# Processing combination: 30400
# Processing combination: 30500
# Processing combination: 30600
# Processing combination: 30700
# Processing combination: 30800
# Processing combination: 30900
# Processing combination: 31000
# Processing combination: 31100
# Processing combination: 31200
# Processing combination: 31300
# Processing combination: 31400
# Processing combination: 31500
# Processing combination: 31600
# Processing combination: 31700
# Processing combination: 31800
# Processing combination: 31900
# Processing combination: 32000
# Processing combination: 32100
# Processing combination: 32200
# Processing combination: 32300
# Processing combination: 32400
# Processing combination: 32500
# Processing combination: 32600
# Processing combination: 32700
# Processing combination: 32800
# Processing combination: 32900
# Processing combination: 33000
# Processing combination: 33100
# Processing combination: 33200
# Processing combination: 33300
# Processing combination: 33400
# Processing combination: 33500
# Processing combination: 33600
# Processing combination: 33700
# Processing combination: 33800
# Processing combination: 33900
# Processing combination: 34000
# Processing combination: 34100
# Processing combination: 34200
# Processing combination: 34300
# Processing combination: 34400
# Processing combination: 34500
# Processing combination: 34600
# Processing combination: 34700
# Processing combination: 34800
# Processing combination: 34900
# Processing combination: 35000
# Processing combination: 35100
# Processing combination: 35200
# Processing combination: 35300
# Processing combination: 35400
# Processing combination: 35500
# Processing combination: 35600
# Processing combination: 35700
# Processing combination: 35800
# Processing combination: 35900
# Processing combination: 36000
# Processing combination: 36100
# Processing combination: 36200
# Processing combination: 36300
# Processing combination: 36400
# Processing combination: 36500
# Processing combination: 36600
# Processing combination: 36700
# Processing combination: 36800
# Processing combination: 36900
# Processing combination: 37000
# Processing combination: 37100
# Processing combination: 37200
# Processing combination: 37300
# Processing combination: 37400
# Processing combination: 37500
# Processing combination: 37600
# Processing combination: 37700
# Processing combination: 37800
# Processing combination: 37900
# Processing combination: 38000
# Processing combination: 38100
# Processing combination: 38200
# Processing combination: 38300
# Processing combination: 38400
# Processing combination: 38500
# Processing combination: 38600
# Processing combination: 38700
# Processing combination: 38800
# Processing combination: 38900
# Processing combination: 39000
# Processing combination: 39100
# Processing combination: 39200
# Processing combination: 39300
# Processing combination: 39400
# Processing combination: 39500
# Processing combination: 39600
# Processing combination: 39700
# Processing combination: 39800
# Processing combination: 39900

# %%
# remove any rows with any nan values
D_rand = D_rand.dropna(subset=['cos_ols'])

# %%
plot_correlations(D_rand, x_vars=['mse_ols'], y_vars=['cos_ols'],show_p_values=True)

# %%
plot_correlations(D_rand, x_vars=['log_det','max_var','min_est'], y_vars=['mse_ols','cos_ols'])

# %% [markdown]
# # orthogonal V library

# %%
GL_orth = np.eye(n_tasks)
YL_orth = make_signal(G = GL_orth,n_channel=n_voxels,make_exact= True)
def kmeans_dictionary(n_parcels, Y):
    """
    Create the initial dictionary using K-Means clustering

    Args:
        n_parcels (int): number of parcels
        Y (np.ndarray): fMRI data (n_obs, n_subjects * n_voxels)

    Returns:
        dict_init (np.ndarray): initial dictionary (n_parcels, n_obs)
    """

    kmeans = MiniBatchKMeans(n_clusters=n_parcels, random_state=2,
                             batch_size=200, n_init=10)
    kmeans = kmeans.fit(Y.T)

    dict_init_ = kmeans.cluster_centers_
    dict_init = (dict_init_.T / np.sqrt((dict_init_ ** 2).sum(1))).T
    similarity = np.exp(np.corrcoef(dict_init))
    embedding = spectral_embedding(similarity, n_components=1)
    order = np.argsort(embedding.T).ravel()
    dict_init = dict_init[order]

    return dict_init.T



VL_orth = kmeans_dictionary(n_parcel, YL_orth)
VL_orth = VL_orth - np.mean(VL_orth, axis=0)
VL_orth = VL_orth / np.sqrt(np.sum(VL_orth**2, axis=0))

V_test = VL_orth
y_test = V_test @ U_true
y_test = y_test + np.random.normal(0, 1, y_test.shape)

GL_orth = VL_orth @ VL_orth.T

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].imshow(VL_orth)
ax[0].set_title('VL_orth')

im2 = ax[1].imshow(GL_orth)
ax[1].set_title('GL_orth')
fig.colorbar(im2, ax=ax[1]) 

plt.show()

# %%
D_orth = ut.build_combinations(GL_orth, strategy='random',offs = offsets,n_iter=10000,n_tasks=8,seed=5545)
D_orth = evaluate_combinations(D_orth, VL_orth, y_test, V_test)
# Out:
# building0
# Processing combination: 0
# Processing combination: 100
# Processing combination: 200
# Processing combination: 300
# Processing combination: 400
# Processing combination: 500
# Processing combination: 600
# Processing combination: 700
# Processing combination: 800
# Processing combination: 900
# Processing combination: 1000
# Processing combination: 1100
# Processing combination: 1200
# Processing combination: 1300
# Processing combination: 1400
# Processing combination: 1500
# Processing combination: 1600
# Processing combination: 1700
# Processing combination: 1800
# Processing combination: 1900
# Processing combination: 2000
# Processing combination: 2100
# Processing combination: 2200
# Processing combination: 2300
# Processing combination: 2400
# Processing combination: 2500
# Processing combination: 2600
# Processing combination: 2700
# Processing combination: 2800
# Processing combination: 2900
# Processing combination: 3000
# Processing combination: 3100
# Processing combination: 3200
# Processing combination: 3300
# Processing combination: 3400
# Processing combination: 3500
# Processing combination: 3600
# Processing combination: 3700
# Processing combination: 3800
# Processing combination: 3900
# Processing combination: 4000
# Processing combination: 4100
# Processing combination: 4200
# Processing combination: 4300
# Processing combination: 4400
# Processing combination: 4500
# Processing combination: 4600
# Processing combination: 4700
# Processing combination: 4800
# Processing combination: 4900
# Processing combination: 5000
# Processing combination: 5100
# Processing combination: 5200
# Processing combination: 5300
# Processing combination: 5400
# Processing combination: 5500
# Processing combination: 5600
# Processing combination: 5700
# Processing combination: 5800
# Processing combination: 5900
# Processing combination: 6000
# Processing combination: 6100
# Processing combination: 6200
# Processing combination: 6300
# Processing combination: 6400
# Processing combination: 6500
# Processing combination: 6600
# Processing combination: 6700
# Processing combination: 6800
# Processing combination: 6900
# Processing combination: 7000
# Processing combination: 7100
# Processing combination: 7200
# Processing combination: 7300
# Processing combination: 7400
# Processing combination: 7500
# Processing combination: 7600
# Processing combination: 7700
# Processing combination: 7800
# Processing combination: 7900
# Processing combination: 8000
# Processing combination: 8100
# Processing combination: 8200
# Processing combination: 8300
# Processing combination: 8400
# Processing combination: 8500
# Processing combination: 8600
# Processing combination: 8700
# Processing combination: 8800
# Processing combination: 8900
# Processing combination: 9000
# Processing combination: 9100
# Processing combination: 9200
# Processing combination: 9300
# Processing combination: 9400
# Processing combination: 9500
# Processing combination: 9600
# Processing combination: 9700
# Processing combination: 9800
# Processing combination: 9900

# %%
D_orth = D_orth.dropna(subset=['cos_ols'])

# %%
plot_correlations(D_orth, x_vars=['mse_ols'], y_vars=['cos_ols'])

# %%
plot_correlations(D_orth, x_vars=['log_det','max_var','min_est'], y_vars=['mse_ols','cos_ols'])

# %% [markdown]
# # Custom Vs

# %%
def custom_G(n_tasks=16, n_groups=4, group_size=4, target_corr=0.4, variance_factors=[1.0, 0.75, 0.5, 0.25]):
    G = np.zeros((n_tasks, n_tasks))
    task_index = 0

    for group in range(n_groups):
        variances = variance_factors

        # Compute covariances based on desired correlation
        covariances = target_corr * np.outer(variance_factors, variance_factors)
        np.fill_diagonal(covariances, variances)

        # Place the block into G
        start, end = task_index, task_index + group_size
        G[start:end, start:end] = covariances

        task_index += group_size

    return G

# %%
def add_correlated_tasks_info(df, group_size):
    """Adds the number of correlated tasks and pairs to the dataframe."""
    n_correlated_tasks_list = []
    n_correlated_pairs_list = []
    for comb in df['combination']:
        group_indices = [task_index // group_size for task_index in comb]
        from collections import Counter
        counts = Counter(group_indices)

        n_correlated_tasks = sum(count for count in counts.values() if count > 1)
        n_correlated_pairs = sum(count * (count - 1) // 2 for count in counts.values())
        n_correlated_tasks_list.append(n_correlated_tasks)
        n_correlated_pairs_list.append(n_correlated_pairs)

    df['n_correlated_tasks'] = n_correlated_tasks_list
    df['n_correlated_pairs'] = n_correlated_pairs_list
    return df

# %%
GL_custom = custom_G(n_tasks=16, n_groups=4, group_size=4, target_corr=1, variance_factors=[1.0, 0.75, 0.5, 0.25])
Y_custom = make_signal(G = GL_custom,n_channel=n_voxels,make_exact= True)
VL_custom = kmeans_dictionary(n_parcel, Y_custom)
VL_custom = VL_custom - np.mean(VL_custom, axis=0)
VL_custom = VL_custom / np.sqrt(np.sum(VL_custom**2, axis=0))

V_test = VL_custom
y_test = V_test @ U_true
y_test = y_test + np.random.normal(0, 1, y_test.shape)

GL_custom = VL_custom @ VL_custom.T
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].imshow(VL_custom)
ax[0].set_title('VL_custom')

ax[1].imshow(GL_custom)
ax[1].set_title('GL_custom')

plt.show()

# %%
D_custom = ut.build_combinations(GL_custom, strategy='random',n_iter=100000,n_tasks=8,seed=17)
D_custom = evaluate_combinations(D_custom, VL_custom, y_test, V_test)

group_size = 4
D_custom = add_correlated_tasks_info(D_custom, group_size)
# Out:
# building0
# building10000
# building20000
# building30000
# building40000
# building50000
# building60000
# building70000
# building80000
# building90000
# Processing combination: 0
# Processing combination: 100
# Processing combination: 200
# Processing combination: 300
# Processing combination: 400
# Processing combination: 500
# Processing combination: 600
# Processing combination: 700
# Processing combination: 800
# Processing combination: 900
# Processing combination: 1000
# Processing combination: 1100
# Processing combination: 1200
# Processing combination: 1300
# Processing combination: 1400
# Processing combination: 1500
# Processing combination: 1600
# Processing combination: 1700
# Processing combination: 1800
# Processing combination: 1900
# Processing combination: 2000
# Processing combination: 2100
# Processing combination: 2200
# Processing combination: 2300
# Processing combination: 2400
# Processing combination: 2500
# Processing combination: 2600
# Processing combination: 2700
# Processing combination: 2800
# Processing combination: 2900
# Processing combination: 3000
# Processing combination: 3100
# Processing combination: 3200
# Processing combination: 3300
# Processing combination: 3400
# Processing combination: 3500
# Processing combination: 3600
# Processing combination: 3700
# Processing combination: 3800
# Processing combination: 3900
# Processing combination: 4000
# Processing combination: 4100
# Processing combination: 4200
# Processing combination: 4300
# Processing combination: 4400
# Processing combination: 4500
# Processing combination: 4600
# Processing combination: 4700
# Processing combination: 4800
# Processing combination: 4900
# Processing combination: 5000
# Processing combination: 5100
# Processing combination: 5200
# Processing combination: 5300
# Processing combination: 5400
# Processing combination: 5500
# Processing combination: 5600
# Processing combination: 5700
# Processing combination: 5800
# Processing combination: 5900
# Processing combination: 6000
# Processing combination: 6100
# Processing combination: 6200
# Processing combination: 6300
# Processing combination: 6400
# Processing combination: 6500
# Processing combination: 6600
# Processing combination: 6700
# Processing combination: 6800
# Processing combination: 6900
# Processing combination: 7000
# Processing combination: 7100
# Processing combination: 7200
# Processing combination: 7300
# Processing combination: 7400
# Processing combination: 7500
# Processing combination: 7600
# Processing combination: 7700
# Processing combination: 7800
# Processing combination: 7900
# Processing combination: 8000
# Processing combination: 8100
# Processing combination: 8200
# Processing combination: 8300
# Processing combination: 8400
# Processing combination: 8500
# Processing combination: 8600
# Processing combination: 8700
# Processing combination: 8800
# Processing combination: 8900
# Processing combination: 9000
# Processing combination: 9100
# Processing combination: 9200
# Processing combination: 9300
# Processing combination: 9400
# Processing combination: 9500
# Processing combination: 9600
# Processing combination: 9700
# Processing combination: 9800
# Processing combination: 9900
# Processing combination: 10000
# Processing combination: 10100
# Processing combination: 10200
# Processing combination: 10300
# Processing combination: 10400
# Processing combination: 10500
# Processing combination: 10600
# Processing combination: 10700
# Processing combination: 10800
# Processing combination: 10900
# Processing combination: 11000
# Processing combination: 11100
# Processing combination: 11200
# Processing combination: 11300
# Processing combination: 11400
# Processing combination: 11500
# Processing combination: 11600
# Processing combination: 11700
# Processing combination: 11800
# Processing combination: 11900
# Processing combination: 12000
# Processing combination: 12100
# Processing combination: 12200
# Processing combination: 12300
# Processing combination: 12400
# Processing combination: 12500
# Processing combination: 12600
# Processing combination: 12700
# Processing combination: 12800
# Processing combination: 12900
# Processing combination: 13000
# Processing combination: 13100
# Processing combination: 13200
# Processing combination: 13300
# Processing combination: 13400
# Processing combination: 13500
# Processing combination: 13600
# Processing combination: 13700
# Processing combination: 13800
# Processing combination: 13900
# Processing combination: 14000
# Processing combination: 14100
# Processing combination: 14200
# Processing combination: 14300
# Processing combination: 14400
# Processing combination: 14500
# Processing combination: 14600
# Processing combination: 14700
# Processing combination: 14800
# Processing combination: 14900
# Processing combination: 15000
# Processing combination: 15100
# Processing combination: 15200
# Processing combination: 15300
# Processing combination: 15400
# Processing combination: 15500
# Processing combination: 15600
# Processing combination: 15700
# Processing combination: 15800
# Processing combination: 15900
# Processing combination: 16000
# Processing combination: 16100
# Processing combination: 16200
# Processing combination: 16300
# Processing combination: 16400
# Processing combination: 16500
# Processing combination: 16600
# Processing combination: 16700
# Processing combination: 16800
# Processing combination: 16900
# Processing combination: 17000
# Processing combination: 17100
# Processing combination: 17200
# Processing combination: 17300
# Processing combination: 17400
# Processing combination: 17500
# Processing combination: 17600
# Processing combination: 17700
# Processing combination: 17800
# Processing combination: 17900
# Processing combination: 18000
# Processing combination: 18100
# Processing combination: 18200
# Processing combination: 18300
# Processing combination: 18400
# Processing combination: 18500
# Processing combination: 18600
# Processing combination: 18700
# Processing combination: 18800
# Processing combination: 18900
# Processing combination: 19000
# Processing combination: 19100
# Processing combination: 19200
# Processing combination: 19300
# Processing combination: 19400
# Processing combination: 19500
# Processing combination: 19600
# Processing combination: 19700
# Processing combination: 19800
# Processing combination: 19900
# Processing combination: 20000
# Processing combination: 20100
# Processing combination: 20200
# Processing combination: 20300
# Processing combination: 20400
# Processing combination: 20500
# Processing combination: 20600
# Processing combination: 20700
# Processing combination: 20800
# Processing combination: 20900
# Processing combination: 21000
# Processing combination: 21100
# Processing combination: 21200
# Processing combination: 21300
# Processing combination: 21400
# Processing combination: 21500
# Processing combination: 21600
# Processing combination: 21700
# Processing combination: 21800
# Processing combination: 21900
# Processing combination: 22000
# Processing combination: 22100
# Processing combination: 22200
# Processing combination: 22300
# Processing combination: 22400
# Processing combination: 22500
# Processing combination: 22600
# Processing combination: 22700
# Processing combination: 22800
# Processing combination: 22900
# Processing combination: 23000
# Processing combination: 23100
# Processing combination: 23200
# Processing combination: 23300
# Processing combination: 23400
# Processing combination: 23500
# Processing combination: 23600
# Processing combination: 23700
# Processing combination: 23800
# Processing combination: 23900
# Processing combination: 24000
# Processing combination: 24100
# Processing combination: 24200
# Processing combination: 24300
# Processing combination: 24400
# Processing combination: 24500
# Processing combination: 24600
# Processing combination: 24700
# Processing combination: 24800
# Processing combination: 24900
# Processing combination: 25000
# Processing combination: 25100
# Processing combination: 25200
# Processing combination: 25300
# Processing combination: 25400
# Processing combination: 25500
# Processing combination: 25600
# Processing combination: 25700
# Processing combination: 25800
# Processing combination: 25900
# Processing combination: 26000
# Processing combination: 26100
# Processing combination: 26200
# Processing combination: 26300
# Processing combination: 26400
# Processing combination: 26500
# Processing combination: 26600
# Processing combination: 26700
# Processing combination: 26800
# Processing combination: 26900
# Processing combination: 27000
# Processing combination: 27100
# Processing combination: 27200
# Processing combination: 27300
# Processing combination: 27400
# Processing combination: 27500
# Processing combination: 27600
# Processing combination: 27700
# Processing combination: 27800
# Processing combination: 27900
# Processing combination: 28000
# Processing combination: 28100
# Processing combination: 28200
# Processing combination: 28300
# Processing combination: 28400
# Processing combination: 28500
# Processing combination: 28600
# Processing combination: 28700
# Processing combination: 28800
# Processing combination: 28900
# Processing combination: 29000
# Processing combination: 29100
# Processing combination: 29200
# Processing combination: 29300
# Processing combination: 29400
# Processing combination: 29500
# Processing combination: 29600
# Processing combination: 29700
# Processing combination: 29800
# Processing combination: 29900
# Processing combination: 30000
# Processing combination: 30100
# Processing combination: 30200
# Processing combination: 30300
# Processing combination: 30400
# Processing combination: 30500
# Processing combination: 30600
# Processing combination: 30700
# Processing combination: 30800
# Processing combination: 30900
# Processing combination: 31000
# Processing combination: 31100
# Processing combination: 31200
# Processing combination: 31300
# Processing combination: 31400
# Processing combination: 31500
# Processing combination: 31600
# Processing combination: 31700
# Processing combination: 31800
# Processing combination: 31900
# Processing combination: 32000
# Processing combination: 32100
# Processing combination: 32200
# Processing combination: 32300
# Processing combination: 32400
# Processing combination: 32500
# Processing combination: 32600
# Processing combination: 32700
# Processing combination: 32800
# Processing combination: 32900
# Processing combination: 33000
# Processing combination: 33100
# Processing combination: 33200
# Processing combination: 33300
# Processing combination: 33400
# Processing combination: 33500
# Processing combination: 33600
# Processing combination: 33700
# Processing combination: 33800
# Processing combination: 33900
# Processing combination: 34000
# Processing combination: 34100
# Processing combination: 34200
# Processing combination: 34300
# Processing combination: 34400
# Processing combination: 34500
# Processing combination: 34600
# Processing combination: 34700
# Processing combination: 34800
# Processing combination: 34900
# Processing combination: 35000
# Processing combination: 35100
# Processing combination: 35200
# Processing combination: 35300
# Processing combination: 35400
# Processing combination: 35500
# Processing combination: 35600
# Processing combination: 35700
# Processing combination: 35800
# Processing combination: 35900
# Processing combination: 36000
# Processing combination: 36100
# Processing combination: 36200
# Processing combination: 36300
# Processing combination: 36400
# Processing combination: 36500
# Processing combination: 36600
# Processing combination: 36700
# Processing combination: 36800
# Processing combination: 36900
# Processing combination: 37000
# Processing combination: 37100
# Processing combination: 37200
# Processing combination: 37300
# Processing combination: 37400
# Processing combination: 37500
# Processing combination: 37600
# Processing combination: 37700
# Processing combination: 37800
# Processing combination: 37900
# Processing combination: 38000
# Processing combination: 38100
# Processing combination: 38200
# Processing combination: 38300
# Processing combination: 38400
# Processing combination: 38500
# Processing combination: 38600
# Processing combination: 38700
# Processing combination: 38800
# Processing combination: 38900
# Processing combination: 39000
# Processing combination: 39100
# Processing combination: 39200
# Processing combination: 39300
# Processing combination: 39400
# Processing combination: 39500
# Processing combination: 39600
# Processing combination: 39700
# Processing combination: 39800
# Processing combination: 39900
# Processing combination: 40000
# Processing combination: 40100
# Processing combination: 40200
# Processing combination: 40300
# Processing combination: 40400
# Processing combination: 40500
# Processing combination: 40600
# Processing combination: 40700
# Processing combination: 40800
# Processing combination: 40900
# Processing combination: 41000
# Processing combination: 41100
# Processing combination: 41200
# Processing combination: 41300
# Processing combination: 41400
# Processing combination: 41500
# Processing combination: 41600
# Processing combination: 41700
# Processing combination: 41800
# Processing combination: 41900
# Processing combination: 42000
# Processing combination: 42100
# Processing combination: 42200
# Processing combination: 42300
# Processing combination: 42400
# Processing combination: 42500
# Processing combination: 42600
# Processing combination: 42700
# Processing combination: 42800
# Processing combination: 42900
# Processing combination: 43000
# Processing combination: 43100
# Processing combination: 43200
# Processing combination: 43300
# Processing combination: 43400
# Processing combination: 43500
# Processing combination: 43600
# Processing combination: 43700
# Processing combination: 43800
# Processing combination: 43900
# Processing combination: 44000
# Processing combination: 44100
# Processing combination: 44200
# Processing combination: 44300
# Processing combination: 44400
# Processing combination: 44500
# Processing combination: 44600
# Processing combination: 44700
# Processing combination: 44800
# Processing combination: 44900
# Processing combination: 45000
# Processing combination: 45100
# Processing combination: 45200
# Processing combination: 45300
# Processing combination: 45400
# Processing combination: 45500
# Processing combination: 45600
# Processing combination: 45700
# Processing combination: 45800
# Processing combination: 45900
# Processing combination: 46000
# Processing combination: 46100
# Processing combination: 46200
# Processing combination: 46300
# Processing combination: 46400
# Processing combination: 46500
# Processing combination: 46600
# Processing combination: 46700
# Processing combination: 46800
# Processing combination: 46900
# Processing combination: 47000
# Processing combination: 47100
# Processing combination: 47200
# Processing combination: 47300
# Processing combination: 47400
# Processing combination: 47500
# Processing combination: 47600
# Processing combination: 47700
# Processing combination: 47800
# Processing combination: 47900
# Processing combination: 48000
# Processing combination: 48100
# Processing combination: 48200
# Processing combination: 48300
# Processing combination: 48400
# Processing combination: 48500
# Processing combination: 48600
# Processing combination: 48700
# Processing combination: 48800
# Processing combination: 48900
# Processing combination: 49000
# Processing combination: 49100
# Processing combination: 49200
# Processing combination: 49300
# Processing combination: 49400
# Processing combination: 49500
# Processing combination: 49600
# Processing combination: 49700
# Processing combination: 49800
# Processing combination: 49900
# Processing combination: 50000
# Processing combination: 50100
# Processing combination: 50200
# Processing combination: 50300
# Processing combination: 50400
# Processing combination: 50500
# Processing combination: 50600
# Processing combination: 50700
# Processing combination: 50800
# Processing combination: 50900
# Processing combination: 51000
# Processing combination: 51100
# Processing combination: 51200
# Processing combination: 51300
# Processing combination: 51400
# Processing combination: 51500
# Processing combination: 51600
# Processing combination: 51700
# Processing combination: 51800
# Processing combination: 51900
# Processing combination: 52000
# Processing combination: 52100
# Processing combination: 52200
# Processing combination: 52300
# Processing combination: 52400
# Processing combination: 52500
# Processing combination: 52600
# Processing combination: 52700
# Processing combination: 52800
# Processing combination: 52900
# Processing combination: 53000
# Processing combination: 53100
# Processing combination: 53200
# Processing combination: 53300
# Processing combination: 53400
# Processing combination: 53500
# Processing combination: 53600
# Processing combination: 53700
# Processing combination: 53800
# Processing combination: 53900
# Processing combination: 54000
# Processing combination: 54100
# Processing combination: 54200
# Processing combination: 54300
# Processing combination: 54400
# Processing combination: 54500
# Processing combination: 54600
# Processing combination: 54700
# Processing combination: 54800
# Processing combination: 54900
# Processing combination: 55000
# Processing combination: 55100
# Processing combination: 55200
# Processing combination: 55300
# Processing combination: 55400
# Processing combination: 55500
# Processing combination: 55600
# Processing combination: 55700
# Processing combination: 55800
# Processing combination: 55900
# Processing combination: 56000
# Processing combination: 56100
# Processing combination: 56200
# Processing combination: 56300
# Processing combination: 56400
# Processing combination: 56500
# Processing combination: 56600
# Processing combination: 56700
# Processing combination: 56800
# Processing combination: 56900
# Processing combination: 57000
# Processing combination: 57100
# Processing combination: 57200
# Processing combination: 57300
# Processing combination: 57400
# Processing combination: 57500
# Processing combination: 57600
# Processing combination: 57700
# Processing combination: 57800
# Processing combination: 57900
# Processing combination: 58000
# Processing combination: 58100
# Processing combination: 58200
# Processing combination: 58300
# Processing combination: 58400
# Processing combination: 58500
# Processing combination: 58600
# Processing combination: 58700
# Processing combination: 58800
# Processing combination: 58900
# Processing combination: 59000
# Processing combination: 59100
# Processing combination: 59200
# Processing combination: 59300
# Processing combination: 59400
# Processing combination: 59500
# Processing combination: 59600
# Processing combination: 59700
# Processing combination: 59800
# Processing combination: 59900
# Processing combination: 60000
# Processing combination: 60100
# Processing combination: 60200
# Processing combination: 60300
# Processing combination: 60400
# Processing combination: 60500
# Processing combination: 60600
# Processing combination: 60700
# Processing combination: 60800
# Processing combination: 60900
# Processing combination: 61000
# Processing combination: 61100
# Processing combination: 61200
# Processing combination: 61300
# Processing combination: 61400
# Processing combination: 61500
# Processing combination: 61600
# Processing combination: 61700
# Processing combination: 61800
# Processing combination: 61900
# Processing combination: 62000
# Processing combination: 62100
# Processing combination: 62200
# Processing combination: 62300
# Processing combination: 62400
# Processing combination: 62500
# Processing combination: 62600
# Processing combination: 62700
# Processing combination: 62800
# Processing combination: 62900
# Processing combination: 63000
# Processing combination: 63100
# Processing combination: 63200
# Processing combination: 63300
# Processing combination: 63400
# Processing combination: 63500
# Processing combination: 63600
# Processing combination: 63700
# Processing combination: 63800
# Processing combination: 63900
# Processing combination: 64000
# Processing combination: 64100
# Processing combination: 64200
# Processing combination: 64300
# Processing combination: 64400
# Processing combination: 64500
# Processing combination: 64600
# Processing combination: 64700
# Processing combination: 64800
# Processing combination: 64900
# Processing combination: 65000
# Processing combination: 65100
# Processing combination: 65200
# Processing combination: 65300
# Processing combination: 65400
# Processing combination: 65500
# Processing combination: 65600
# Processing combination: 65700
# Processing combination: 65800
# Processing combination: 65900
# Processing combination: 66000
# Processing combination: 66100
# Processing combination: 66200
# Processing combination: 66300
# Processing combination: 66400
# Processing combination: 66500
# Processing combination: 66600
# Processing combination: 66700
# Processing combination: 66800
# Processing combination: 66900
# Processing combination: 67000
# Processing combination: 67100
# Processing combination: 67200
# Processing combination: 67300
# Processing combination: 67400
# Processing combination: 67500
# Processing combination: 67600
# Processing combination: 67700
# Processing combination: 67800
# Processing combination: 67900
# Processing combination: 68000
# Processing combination: 68100
# Processing combination: 68200
# Processing combination: 68300
# Processing combination: 68400
# Processing combination: 68500
# Processing combination: 68600
# Processing combination: 68700
# Processing combination: 68800
# Processing combination: 68900
# Processing combination: 69000
# Processing combination: 69100
# Processing combination: 69200
# Processing combination: 69300
# Processing combination: 69400
# Processing combination: 69500
# Processing combination: 69600
# Processing combination: 69700
# Processing combination: 69800
# Processing combination: 69900
# Processing combination: 70000
# Processing combination: 70100
# Processing combination: 70200
# Processing combination: 70300
# Processing combination: 70400
# Processing combination: 70500
# Processing combination: 70600
# Processing combination: 70700
# Processing combination: 70800
# Processing combination: 70900
# Processing combination: 71000
# Processing combination: 71100
# Processing combination: 71200
# Processing combination: 71300
# Processing combination: 71400
# Processing combination: 71500
# Processing combination: 71600
# Processing combination: 71700
# Processing combination: 71800
# Processing combination: 71900
# Processing combination: 72000
# Processing combination: 72100
# Processing combination: 72200
# Processing combination: 72300
# Processing combination: 72400
# Processing combination: 72500
# Processing combination: 72600
# Processing combination: 72700
# Processing combination: 72800
# Processing combination: 72900
# Processing combination: 73000
# Processing combination: 73100
# Processing combination: 73200
# Processing combination: 73300
# Processing combination: 73400
# Processing combination: 73500
# Processing combination: 73600
# Processing combination: 73700
# Processing combination: 73800
# Processing combination: 73900
# Processing combination: 74000
# Processing combination: 74100
# Processing combination: 74200
# Processing combination: 74300
# Processing combination: 74400
# Processing combination: 74500
# Processing combination: 74600
# Processing combination: 74700
# Processing combination: 74800
# Processing combination: 74900
# Processing combination: 75000
# Processing combination: 75100
# Processing combination: 75200
# Processing combination: 75300
# Processing combination: 75400
# Processing combination: 75500
# Processing combination: 75600
# Processing combination: 75700
# Processing combination: 75800
# Processing combination: 75900
# Processing combination: 76000
# Processing combination: 76100
# Processing combination: 76200
# Processing combination: 76300
# Processing combination: 76400
# Processing combination: 76500
# Processing combination: 76600
# Processing combination: 76700
# Processing combination: 76800
# Processing combination: 76900
# Processing combination: 77000
# Processing combination: 77100
# Processing combination: 77200
# Processing combination: 77300
# Processing combination: 77400
# Processing combination: 77500
# Processing combination: 77600
# Processing combination: 77700
# Processing combination: 77800
# Processing combination: 77900
# Processing combination: 78000
# Processing combination: 78100
# Processing combination: 78200
# Processing combination: 78300
# Processing combination: 78400
# Processing combination: 78500
# Processing combination: 78600
# Processing combination: 78700
# Processing combination: 78800
# Processing combination: 78900
# Processing combination: 79000
# Processing combination: 79100
# Processing combination: 79200
# Processing combination: 79300
# Processing combination: 79400
# Processing combination: 79500
# Processing combination: 79600
# Processing combination: 79700
# Processing combination: 79800
# Processing combination: 79900
# Processing combination: 80000
# Processing combination: 80100
# Processing combination: 80200
# Processing combination: 80300
# Processing combination: 80400
# Processing combination: 80500
# Processing combination: 80600
# Processing combination: 80700
# Processing combination: 80800
# Processing combination: 80900
# Processing combination: 81000
# Processing combination: 81100
# Processing combination: 81200
# Processing combination: 81300
# Processing combination: 81400
# Processing combination: 81500
# Processing combination: 81600
# Processing combination: 81700
# Processing combination: 81800
# Processing combination: 81900
# Processing combination: 82000
# Processing combination: 82100
# Processing combination: 82200
# Processing combination: 82300
# Processing combination: 82400
# Processing combination: 82500
# Processing combination: 82600
# Processing combination: 82700
# Processing combination: 82800
# Processing combination: 82900
# Processing combination: 83000
# Processing combination: 83100
# Processing combination: 83200
# Processing combination: 83300
# Processing combination: 83400
# Processing combination: 83500
# Processing combination: 83600
# Processing combination: 83700
# Processing combination: 83800
# Processing combination: 83900
# Processing combination: 84000
# Processing combination: 84100
# Processing combination: 84200
# Processing combination: 84300
# Processing combination: 84400
# Processing combination: 84500
# Processing combination: 84600
# Processing combination: 84700
# Processing combination: 84800
# Processing combination: 84900
# Processing combination: 85000
# Processing combination: 85100
# Processing combination: 85200
# Processing combination: 85300
# Processing combination: 85400
# Processing combination: 85500
# Processing combination: 85600
# Processing combination: 85700
# Processing combination: 85800
# Processing combination: 85900
# Processing combination: 86000
# Processing combination: 86100
# Processing combination: 86200
# Processing combination: 86300
# Processing combination: 86400
# Processing combination: 86500
# Processing combination: 86600
# Processing combination: 86700
# Processing combination: 86800
# Processing combination: 86900
# Processing combination: 87000
# Processing combination: 87100
# Processing combination: 87200
# Processing combination: 87300
# Processing combination: 87400
# Processing combination: 87500
# Processing combination: 87600
# Processing combination: 87700
# Processing combination: 87800
# Processing combination: 87900
# Processing combination: 88000
# Processing combination: 88100
# Processing combination: 88200
# Processing combination: 88300
# Processing combination: 88400
# Processing combination: 88500
# Processing combination: 88600
# Processing combination: 88700
# Processing combination: 88800
# Processing combination: 88900
# Processing combination: 89000
# Processing combination: 89100
# Processing combination: 89200
# Processing combination: 89300
# Processing combination: 89400
# Processing combination: 89500
# Processing combination: 89600
# Processing combination: 89700
# Processing combination: 89800
# Processing combination: 89900
# Processing combination: 90000
# Processing combination: 90100
# Processing combination: 90200
# Processing combination: 90300
# Processing combination: 90400
# Processing combination: 90500
# Processing combination: 90600
# Processing combination: 90700
# Processing combination: 90800
# Processing combination: 90900
# Processing combination: 91000
# Processing combination: 91100
# Processing combination: 91200
# Processing combination: 91300
# Processing combination: 91400
# Processing combination: 91500
# Processing combination: 91600
# Processing combination: 91700
# Processing combination: 91800
# Processing combination: 91900
# Processing combination: 92000
# Processing combination: 92100
# Processing combination: 92200
# Processing combination: 92300
# Processing combination: 92400
# Processing combination: 92500
# Processing combination: 92600
# Processing combination: 92700
# Processing combination: 92800
# Processing combination: 92900
# Processing combination: 93000
# Processing combination: 93100
# Processing combination: 93200
# Processing combination: 93300
# Processing combination: 93400
# Processing combination: 93500
# Processing combination: 93600
# Processing combination: 93700
# Processing combination: 93800
# Processing combination: 93900
# Processing combination: 94000
# Processing combination: 94100
# Processing combination: 94200
# Processing combination: 94300
# Processing combination: 94400
# Processing combination: 94500
# Processing combination: 94600
# Processing combination: 94700
# Processing combination: 94800
# Processing combination: 94900
# Processing combination: 95000
# Processing combination: 95100
# Processing combination: 95200
# Processing combination: 95300
# Processing combination: 95400
# Processing combination: 95500
# Processing combination: 95600
# Processing combination: 95700
# Processing combination: 95800
# Processing combination: 95900
# Processing combination: 96000
# Processing combination: 96100
# Processing combination: 96200
# Processing combination: 96300
# Processing combination: 96400
# Processing combination: 96500
# Processing combination: 96600
# Processing combination: 96700
# Processing combination: 96800
# Processing combination: 96900
# Processing combination: 97000
# Processing combination: 97100
# Processing combination: 97200
# Processing combination: 97300
# Processing combination: 97400
# Processing combination: 97500
# Processing combination: 97600
# Processing combination: 97700
# Processing combination: 97800
# Processing combination: 97900
# Processing combination: 98000
# Processing combination: 98100
# Processing combination: 98200
# Processing combination: 98300
# Processing combination: 98400
# Processing combination: 98500
# Processing combination: 98600
# Processing combination: 98700
# Processing combination: 98800
# Processing combination: 98900
# Processing combination: 99000
# Processing combination: 99100
# Processing combination: 99200
# Processing combination: 99300
# Processing combination: 99400
# Processing combination: 99500
# Processing combination: 99600
# Processing combination: 99700
# Processing combination: 99800
# Processing combination: 99900

# %%
# remove any rows with any nan values
D_custom = D_custom.dropna(subset=['cos_ols'])

# %%
plot_correlations(D_custom, x_vars=['mse_ols'], y_vars=['cos_ols'])

# %%
plot_correlations(D_custom, x_vars=['log_det','max_var','min_est'], y_vars=['mse_ols','cos_ols'])

# %% [markdown]
# # MDTB Vs

# %%
# mdtb vs based on HBP
model_dir = 'Y:/data/Cerebellum/ProbabilisticParcellationModel/Models'
if not os.path.exists(model_dir):
    model_dir = '/cifs/diedrichsen/data/Cerebellum/ProbabilisticParcellationModel/Models'
    
model_name = f'/Models_03/NettekovenSym32_space-MNISymC2'
fname = model_dir + model_name
with open(fname + '.pickle', 'rb') as file:
        full_model = pickle.load(file)[0]

# load emission model & Vs for mdtb ses-1
mdtb_1_emission = full_model.emissions[0]
mdtb_1_Vs = mdtb_1_emission.V

#make into np array
VL_mdtb = mdtb_1_Vs.detach().numpy()
GL_mdtb = VL_mdtb @ VL_mdtb.T

mdtb_2_emission = full_model.emissions[1]
mdtb_2_Vs = mdtb_2_emission.V

#make into np array
VL_mdtb_2 = mdtb_2_Vs.detach().numpy()
GL_mdtb_2 = VL_mdtb_2 @ VL_mdtb_2.T

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].imshow(VL_mdtb)
ax[0].set_title('VL_mdtb')

ax[1].imshow(GL_mdtb)
ax[1].set_title('GL_mdtb')

plt.show()

# %%
D_mdtb = ut.build_combinations(GL_mdtb, strategy='random',n_iter=400,n_tasks=8,seed=3)
A_mdtb = D_mdtb[D_mdtb['offset'] == 0.001]
A_mdtb = evaluate_U_MSE(A_mdtb, VL_mdtb, y_test, V_test)
